# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
ls /gdrive/Shared\ drives/OpenPTV/JHU_data
# Out:
#  jhu_t4_n150.h5   pairs.py                  trajectories.npz
#  pairs.ipynb      read_trajectories.ipynb  'trajectories_t=2_steps=120.npz'

# %%
import numpy as np

# %%
d = np.load('/gdrive/Shared drives/OpenPTV/JHU_data/trajectories_t=2_steps=120.npz',fix_imports=True)
# d = np.load('/gdrive/Shared drives/OpenPTV/JHU_data/trajectories.npz',fix_imports=True)

# %%
d.files
# Out:
# ['arr_0', 'arr_1']

# %%
import matplotlib.pyplot as plt
d['arr_0'].shape
# Out:
# (121, 8000, 3)

# %%
plt.plot(d['arr_0'][0][:100])
